# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Data Loading

# %%
data=pd.read_csv("C:\\Users\\punith yc\\Downloads\\Dataset New.csv")

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
data.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# ...

# %%
len(data['Item_Type'].unique())
# Out:
# 16

# %%
data.describe(include="object")
# Out:
#        Item_Identifier Item_Fat_Content              Item_Type  \
# count             8523             8523                   8523
# unique            1559                5                     16
# top              FDW13          Low Fat  Fruits and Vegetables
# freq                10             5089                   1232
#
#        Outlet_Identifier Outlet_Size Outlet_Location_Type        Outlet_Type
# count               8523        6113                 8523               8523
# unique                10           3                    3                  4
# top               OUT027      Medium               Tier 3  Supermarket Type1
# freq                 935        2793                 3350               5577

# %%
data.describe(include='float')
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Item_Outlet_Sales
# count  7060.000000      8523.000000  8523.000000        8523.000000
# mean     12.857645         0.066132   140.992782        2181.288914
# std       4.643456         0.051598    62.275067        1706.499616
# min       4.555000         0.000000    31.290000          33.290000
# 25%       8.773750         0.026989    93.826500         834.247400
# 50%      12.600000         0.053931   143.012800        1794.331000
# 75%      16.850000         0.094585   185.643700        3101.296400
# max      21.350000         0.328391   266.888400       13086.964800

# %%
data.describe(include='int')
# Out:
#        Outlet_Establishment_Year
# count                8523.000000
# mean                 1997.831867
# std                     8.371760
# min                  1985.000000
# 25%                  1987.000000
# 50%                  1999.000000
# 75%                  2004.000000
# max                  2009.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
data.shape
# Out:
# (8523, 12)

# %%
data.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
insects=["ants",'cricket','bee']

# %%
type(insects)
# Out:
# list

# %%
pd.DataFrame(insects,columns=['insects'])
# Out:
#    insects
# 0     ants
# 1  cricket
# 2      bee

# %%
animals={'mammals':['cow','sheep','lion'],
         'reptiles':['crocodile','lizard','snake'],
         'insects':['ant','cricket','bee']}

# %%
type(animals)
# Out:
# dict

# %%
pd.DataFrame(animals)
# Out:
#   mammals   reptiles  insects
# 0     cow  crocodile      ant
# 1   sheep     lizard  cricket
# 2    lion      snake      bee

# %%
mammals=['cow','sheep','lion']

# %%
type(mammals)
# Out:
# list

# %%
pd.DataFrame(mammals,columns=['mammals'])
# Out:
#   mammals
# 0     cow
# 1   sheep
# 2    lion

# %%
reptiles=['crocodile','lizard','snake']

# %%
pd.DataFrame(reptiles,columns=['reptiles'])
# Out:
#     reptiles
# 0  crocodile
# 1     lizard
# 2      snake

# %%
insects=['ant','cricket','bee']

# %%
pd.DataFrame(insects,columns=['insects'])
# Out:
#    insects
# 0      ant
# 1  cricket
# 2      bee

# %%
data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
data.set_index('Outlet_Establishment_Year',inplace=True)

# %%
data
# Out:
#                           Item_Identifier  Item_Weight Item_Fat_Content  \
# Outlet_Establishment_Year
# 1999                                FDA15        9.300          Low Fat
# 2009                                DRC01        5.920          Regular
# 1999                                FDN15       17.500          Low Fat
# 1998                                FDX07       19.200          Regular
# 1987                                NCD19        8.930          Low Fat
# ...                                   ...          ...              ...
# 1987                                FDF22        6.865          Low Fat
# 2002                                FDS36        8.380          Regular
# 2004                                NCJ29       10.600          Low Fat
# 2009                                FDN46        7.210          Regular
# 1997                                DRG01       14.800          Low Fat
#
# ...

# %%
data.iloc[1999]
# Out:
# Item_Identifier                     FDZ21
# Item_Weight                          17.6
# Item_Fat_Content                  Regular
# Item_Visibility                  0.039222
# Item_Type                     Snack Foods
# Item_MRP                           97.241
# Outlet_Identifier                  OUT046
# Outlet_Size                         Small
# Outlet_Location_Type               Tier 1
# Outlet_Type             Supermarket Type1
# Item_Outlet_Sales                 193.082
# Name: 1997, dtype: object

# %%
data.reset_index(inplace=True)

# %%
data
# Out:
#       Outlet_Establishment_Year Item_Identifier  Item_Weight Item_Fat_Content  \
# 0                          1999           FDA15        9.300          Low Fat
# 1                          2009           DRC01        5.920          Regular
# 2                          1999           FDN15       17.500          Low Fat
# 3                          1998           FDX07       19.200          Regular
# 4                          1987           NCD19        8.930          Low Fat
# ...                         ...             ...          ...              ...
# 8518                       1987           FDF22        6.865          Low Fat
# 8519                       2002           FDS36        8.380          Regular
# 8520                       2004           NCJ29       10.600          Low Fat
# 8521                       2009           FDN46        7.210          Regular
# 8522                       1997           DRG01       14.800          Low Fat
#
# ...

# %%
data.iloc[8518]
# Out:
# Outlet_Establishment_Year                 1987
# Item_Identifier                          FDF22
# Item_Weight                              6.865
# Item_Fat_Content                       Low Fat
# Item_Visibility                       0.056783
# Item_Type                          Snack Foods
# Item_MRP                              214.5218
# Outlet_Identifier                       OUT013
# Outlet_Size                               High
# Outlet_Location_Type                    Tier 3
# Outlet_Type                  Supermarket Type1
# Item_Outlet_Sales                    2778.3834
# Name: 8518, dtype: object

# %%
data.set_index(['Outlet_Establishment_Year','Item_Identifier'],inplace=True)

# %%
data
# Out:
#                                            Item_Weight Item_Fat_Content  \
# Outlet_Establishment_Year Item_Identifier
# 1999                      FDA15                  9.300          Low Fat
# 2009                      DRC01                  5.920          Regular
# 1999                      FDN15                 17.500          Low Fat
# 1998                      FDX07                 19.200          Regular
# 1987                      NCD19                  8.930          Low Fat
# ...                                                ...              ...
#                           FDF22                  6.865          Low Fat
# 2002                      FDS36                  8.380          Regular
# 2004                      NCJ29                 10.600          Low Fat
# 2009                      FDN46                  7.210          Regular
# 1997                      DRG01                 14.800          Low Fat
#
# ...

# %%
data.reset_index()
# Out:
#       Outlet_Establishment_Year Item_Identifier  Item_Weight Item_Fat_Content  \
# 0                          1999           FDA15        9.300          Low Fat
# 1                          2009           DRC01        5.920          Regular
# 2                          1999           FDN15       17.500          Low Fat
# 3                          1998           FDX07       19.200          Regular
# 4                          1987           NCD19        8.930          Low Fat
# ...                         ...             ...          ...              ...
# 8518                       1987           FDF22        6.865          Low Fat
# 8519                       2002           FDS36        8.380          Regular
# 8520                       2004           NCJ29       10.600          Low Fat
# 8521                       2009           FDN46        7.210          Regular
# 8522                       1997           DRG01       14.800          Low Fat
#
# ...

# %%
data
# Out:
#                                            Item_Weight Item_Fat_Content  \
# Outlet_Establishment_Year Item_Identifier
# 1999                      FDA15                  9.300          Low Fat
# 2009                      DRC01                  5.920          Regular
# 1999                      FDN15                 17.500          Low Fat
# 1998                      FDX07                 19.200          Regular
# 1987                      NCD19                  8.930          Low Fat
# ...                                                ...              ...
#                           FDF22                  6.865          Low Fat
# 2002                      FDS36                  8.380          Regular
# 2004                      NCJ29                 10.600          Low Fat
# 2009                      FDN46                  7.210          Regular
# 1997                      DRG01                 14.800          Low Fat
#
# ...

# %%
highest_sales=(data['Item_Outlet_Sales']>4000) & (data['Outlet_Size']=='Medium')

# %%
data.loc[highest_sales,'Item_Fat_Content']
# Out:
# Outlet_Establishment_Year  Item_Identifier
# 1985                       FDP10              Low Fat
#                            FDW12              Regular
# 2009                       FDC02              Low Fat
#                            FDK21              Low Fat
# 1999                       NCZ18              low fat
#                                                ...
# 1985                       DRK37              Low Fat
#                            DRG13              Low Fat
# 2009                       FDO03              Regular
# 1985                       NCN18              Low Fat
# 2009                       FDF05              Low Fat
# Name: Item_Fat_Content, Length: 588, dtype: object

# %%
data.reset_index(inplace=True)

# %%
data
# Out:
#       Outlet_Establishment_Year Item_Identifier  Item_Weight Item_Fat_Content  \
# 0                          1999           FDA15        9.300          Low Fat
# 1                          2009           DRC01        5.920          Regular
# 2                          1999           FDN15       17.500          Low Fat
# 3                          1998           FDX07       19.200          Regular
# 4                          1987           NCD19        8.930          Low Fat
# ...                         ...             ...          ...              ...
# 8518                       1987           FDF22        6.865          Low Fat
# 8519                       2002           FDS36        8.380          Regular
# 8520                       2004           NCJ29       10.600          Low Fat
# 8521                       2009           FDN46        7.210          Regular
# 8522                       1997           DRG01       14.800          Low Fat
#
# ...

# %%
data.reset_index()
# Out:
#       index  Outlet_Establishment_Year Item_Identifier  Item_Weight  \
# 0         0                       1999           FDA15        9.300
# 1         1                       2009           DRC01        5.920
# 2         2                       1999           FDN15       17.500
# 3         3                       1998           FDX07       19.200
# 4         4                       1987           NCD19        8.930
# ...     ...                        ...             ...          ...
# 8518   8518                       1987           FDF22        6.865
# 8519   8519                       2002           FDS36        8.380
# 8520   8520                       2004           NCJ29       10.600
# 8521   8521                       2009           FDN46        7.210
# 8522   8522                       1997           DRG01       14.800
#
#      Item_Fat_Content  Item_Visibility              Item_Type  Item_MRP  \
# 0             Low Fat         0.016047                  Dairy  249.8092
# ...

# %%
data
# Out:
#       Outlet_Establishment_Year Item_Identifier  Item_Weight Item_Fat_Content  \
# 0                          1999           FDA15        9.300          Low Fat
# 1                          2009           DRC01        5.920          Regular
# 2                          1999           FDN15       17.500          Low Fat
# 3                          1998           FDX07       19.200          Regular
# 4                          1987           NCD19        8.930          Low Fat
# ...                         ...             ...          ...              ...
# 8518                       1987           FDF22        6.865          Low Fat
# 8519                       2002           FDS36        8.380          Regular
# 8520                       2004           NCJ29       10.600          Low Fat
# 8521                       2009           FDN46        7.210          Regular
# 8522                       1997           DRG01       14.800          Low Fat
#
# ...

# %%
establishment_year=[2009,1997,2004,2002]

# %%
highest_sales1=data['Outlet_Establishment_Year'].isin(establishment_year)

# %%
data.loc[highest_sales1]
# Out:
#       Outlet_Establishment_Year Item_Identifier  Item_Weight Item_Fat_Content  \
# 1                          2009           DRC01        5.920          Regular
# 5                          2009           FDP36       10.395          Regular
# 8                          2002           FDH17       16.200          Regular
# 11                         1997           FDA03       18.500          Regular
# 13                         1997           FDS46       17.600          Regular
# ...                         ...             ...          ...              ...
# 8517                       1997           FDF53       20.750              reg
# 8519                       2002           FDS36        8.380          Regular
# 8520                       2004           NCJ29       10.600          Low Fat
# 8521                       2009           FDN46        7.210          Regular
# 8522                       1997           DRG01       14.800          Low Fat
#
# ...

# %% [markdown]
#     name  village
# 0   xyz    abc
# 1   abc    xyz
# 2   efg    efhh

# %%
details={'name':['xyz','abc','efg'],'village':['abc','xyz','efhh']}

# %%
pd.DataFrame(details)
# Out:
#   name village
# 0  xyz     abc
# 1  abc     xyz
# 2  efg    efhh

# %%
details=[10]

# %%
pd.DataFrame(details,columns=['cdc'])
# Out:
#    cdc
# 0   10

# %% [markdown]
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# name:Dinner

# %%
quantities={'Flour':'4 cups','Milk':'1 cup','Eggs':' 2 large','Spam':'1 can'}

# %%
pd.Series(quantities,name='Dinner')
# Out:
# Flour      4 cups
# Milk        1 cup
# Eggs      2 large
# Spam        1 can
# Name: Dinner, dtype: object

# %%
quantities=[10]

# %%
pd.DataFrame(quantities,columns=['hello'])
# Out:
#    hello
# 0     10

# %%
data
# Out:
#       Outlet_Establishment_Year Item_Identifier  Item_Weight Item_Fat_Content  \
# 0                          1999           FDA15        9.300          Low Fat
# 1                          2009           DRC01        5.920          Regular
# 2                          1999           FDN15       17.500          Low Fat
# 3                          1998           FDX07       19.200          Regular
# 4                          1987           NCD19        8.930          Low Fat
# ...                         ...             ...          ...              ...
# 8518                       1987           FDF22        6.865          Low Fat
# 8519                       2002           FDS36        8.380          Regular
# 8520                       2004           NCJ29       10.600          Low Fat
# 8521                       2009           FDN46        7.210          Regular
# 8522                       1997           DRG01       14.800          Low Fat
#
# ...

# %%
data.iloc[0]
# Out:
# Outlet_Establishment_Year                 1999
# Item_Identifier                          FDA15
# Item_Weight                                9.3
# Item_Fat_Content                       Low Fat
# Item_Visibility                       0.016047
# Item_Type                                Dairy
# Item_MRP                              249.8092
# Outlet_Identifier                       OUT049
# Outlet_Size                             Medium
# Outlet_Location_Type                    Tier 1
# Outlet_Type                  Supermarket Type1
# Item_Outlet_Sales                     3735.138
# Name: 0, dtype: object

# %%
data.iloc[[0,1,2],1]
# Out:
# 0    FDA15
# 1    DRC01
# 2    FDN15
# Name: Item_Identifier, dtype: object

# %%
data.iloc[[0,1,2],2]
# Out:
# 0     9.30
# 1     5.92
# 2    17.50
# Name: Item_Weight, dtype: float64

# %%
data.iloc[[0,1,2],3]
# Out:
# 0    Low Fat
# 1    Regular
# 2    Low Fat
# Name: Item_Fat_Content, dtype: object

# %%
recipe = pd.Series(['4 cups', '1 cup', '2 large', '1 can'], index=['Flour', 'Milk', 'Eggs', 'Spam'], name='Dinner')

# %%
type(recipe)
# Out:
# pandas.core.series.Series

# %%
data
# Out:
#       Outlet_Establishment_Year Item_Identifier  Item_Weight Item_Fat_Content  \
# 0                          1999           FDA15        9.300          Low Fat
# 1                          2009           DRC01        5.920          Regular
# 2                          1999           FDN15       17.500          Low Fat
# 3                          1998           FDX07       19.200          Regular
# 4                          1987           NCD19        8.930          Low Fat
# ...                         ...             ...          ...              ...
# 8518                       1987           FDF22        6.865          Low Fat
# 8519                       2002           FDS36        8.380          Regular
# 8520                       2004           NCJ29       10.600          Low Fat
# 8521                       2009           FDN46        7.210          Regular
# 8522                       1997           DRG01       14.800          Low Fat
#
# ...

# %%
#item_sales=data['Item_Weight']*data['Item_MRP']

# %%
data['item_sales']=data['Item_Weight']

# %%
data
# Out:
#       Outlet_Establishment_Year Item_Identifier  Item_Weight Item_Fat_Content  \
# 0                          1999           FDA15        9.300          Low Fat
# 1                          2009           DRC01        5.920          Regular
# 2                          1999           FDN15       17.500          Low Fat
# 3                          1998           FDX07       19.200          Regular
# 4                          1987           NCD19        8.930          Low Fat
# ...                         ...             ...          ...              ...
# 8518                       1987           FDF22        6.865          Low Fat
# 8519                       2002           FDS36        8.380          Regular
# 8520                       2004           NCJ29       10.600          Low Fat
# 8521                       2009           FDN46        7.210          Regular
# 8522                       1997           DRG01       14.800          Low Fat
#
# ...

# %%
data.shape
# Out:
# (8523, 13)

# %%
data.columns
# Out:
# Index(['Outlet_Establishment_Year', 'Item_Identifier', 'Item_Weight',
#        'Item_Fat_Content', 'Item_Visibility', 'Item_Type', 'Item_MRP',
#        'Outlet_Identifier', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales', 'item_sales'],
#       dtype='object')

# %%
d1=data.isnull().sum()

# %%
d2=data.notnull().sum()

# %%
d2-d1
# Out:
# Outlet_Establishment_Year    8523
# Item_Identifier              8523
# Item_Weight                  5597
# Item_Fat_Content             8523
# Item_Visibility              8523
# Item_Type                    8523
# Item_MRP                     8523
# Outlet_Identifier            8523
# Outlet_Size                  3703
# Outlet_Location_Type         8523
# Outlet_Type                  8523
# Item_Outlet_Sales            8523
# item_sales                   5597
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Outlet_Establishment_Year  8523 non-null   int64
#  1   Item_Identifier            8523 non-null   object
#  2   Item_Weight                7060 non-null   float64
#  3   Item_Fat_Content           8523 non-null   object
#  4   Item_Visibility            8523 non-null   float64
#  5   Item_Type                  8523 non-null   object
#  6   Item_MRP                   8523 non-null   float64
#  7   Outlet_Identifier          8523 non-null   object
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
#  12  item_sales                 7060 non-null   float64
# ...

# %%
data['Item_MRP'].rolling(2).sum()
# Out:
# 0            NaN
# 1       298.0784
# 2       189.8872
# 3       323.7130
# 4       235.9564
#           ...
# 8518    393.3536
# 8519    322.6788
# 8520    193.2794
# 8521    188.2556
# 8522    178.6002
# Name: Item_MRP, Length: 8523, dtype: float64

# %%
my_list=[1,2,3,4,5]

# %%
my_list
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# d3=pd.Series(my_list,index=[0,9,8,7,6],name='table')

# %%
d3=pd.Series(my_list,index=[0,9,8,7,6],name='table')

# %% [markdown]
# d3=pd.Series(my_list,index=[0,9,8,7,6],name='table')

# %%
d3
# Out:
# 0    1
# 9    2
# 8    3
# 7    4
# 6    5
# Name: table, dtype: int64

# %%
def multiply_by_2(d3):
    return d3*5

# %%
d3.pipe(multiply_by_2)
# Out:
# 0     5
# 9    10
# 8    15
# 7    20
# 6    25
# Name: table, dtype: int64

# %%
d3.dtypes
# Out:
# dtype('int64')

# %%
dt='2023-08-30'

# %%
date=pd.to_datetime(dt)

# %%
date.year
# Out:
# 2023

# %%
date.month
# Out:
# 8

# %%
date.day
# Out:
# 30

# %%
dt1=['2023-08-30','2023-08-31','2021-08-03','2021-08-30']

# %%
date1=pd.to_datetime(dt1,format='%y/%m/%d')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 date1=pd.to_datetime(dt1,format='%y/%m/%d')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1082, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1080         result = _convert_and_box_cache(argc, cache_array)
#    1081     else:
# -> 1082         result = convert_listlike(argc, format)
#    1083 else:
#    1084     result = convert_listlike(np.array([arg]), format)[0]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:453, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     451 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     452 if format is not None and format != "mixed":
# ...

# %% [markdown]
# #

# %%
date1

# %%
date1.year

# %%
date1.month

# %%
date1.day

# %%
pd.date_range(start='08-21-2023',end='01-08-2024',freq='d')

# %%
data

# %%
data

# %%
dummy=pd.get_dummies(data[['Item_Fat_Content','Outlet_Location_Type']],drop_first=True)

# %%
dummy

# %%
data.iloc[0:5,1:]

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("C:\\Users\\punith yc\\Downloads\\Dataset New.csv")

# %%
data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
data.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# ...

# %%
len(data)
# Out:
# 8523

# %%
data.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
data.describe(include='all')
# Out:
#        Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# count             8523  7060.000000             8523      8523.000000
# unique            1559          NaN                5              NaN
# top              FDW13          NaN          Low Fat              NaN
# freq                10          NaN             5089              NaN
# mean               NaN    12.857645              NaN         0.066132
# std                NaN     4.643456              NaN         0.051598
# min                NaN     4.555000              NaN         0.000000
# 25%                NaN     8.773750              NaN         0.026989
# 50%                NaN    12.600000              NaN         0.053931
# 75%                NaN    16.850000              NaN         0.094585
# max                NaN    21.350000              NaN         0.328391
#
#                     Item_Type     Item_MRP Outlet_Identifier  \
# count                    8523  8523.000000              8523
# ...

# %%
data['Outlet_Identifier'].unique()
# Out:
# array(['OUT049', 'OUT018', 'OUT010', 'OUT013', 'OUT027', 'OUT045',
#        'OUT017', 'OUT046', 'OUT035', 'OUT019'], dtype=object)

# %%
data['Outlet_Identifier'].nunique()
# Out:
# 10

# %%
data.shape
# Out:
# (8523, 12)

# %%
insects=["fbj",'dsjvf','dkdjdbj']

# %%
pd.DataFrame(insects,columns=['name'],index=[1,2,3])
# Out:
#       name
# 1      fbj
# 2    dsjvf
# 3  dkdjdbj

# %%
data1 = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Emily'],
    'Age': [25, 30, 22, 35, 28],
    'City': ['New York', 'San Francisco', 'Los Angeles', 'Chicago', 'Boston']
}

# %%
data2=pd.DataFrame(data1)

# %%
data2
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30  San Francisco
# 2  Charlie   22    Los Angeles
# 3    David   35        Chicago
# 4    Emily   28         Boston

# %%
data2.loc[0,'Name']
# Out:
# 'Alice'

# %%
data2.iloc[:,1]
# Out:
# 0    25
# 1    30
# 2    22
# 3    35
# 4    28
# Name: Age, dtype: int64

# %%
data2[data2['Age']>25]
# Out:
#     Name  Age           City
# 1    Bob   30  San Francisco
# 3  David   35        Chicago
# 4  Emily   28         Boston

# %%
data2.loc[data2['Age']>25]
# Out:
#     Name  Age           City
# 1    Bob   30  San Francisco
# 3  David   35        Chicago
# 4  Emily   28         Boston

# %%
data2.at[0,'Name']
# Out:
# 'Alice'

# %%
data2['Na']=['name','age','city','hjrf','efkj']

# %%
data2
# Out:
#       Name  Age           City    Na
# 0    Alice   25       New York  name
# 1      Bob   30  San Francisco   age
# 2  Charlie   22    Los Angeles  city
# 3    David   35        Chicago  hjrf
# 4    Emily   28         Boston  efkj

# %%
data2.drop(columns=['Na'],axis=1,inplace=True)

# %%
data2
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30  San Francisco
# 2  Charlie   22    Los Angeles
# 3    David   35        Chicago
# 4    Emily   28         Boston

# %%
data3=df = pd.Series( [1, 2, 3,] ,index=['X', 'Y', 'Z'],name='type')

# %%
data3
# Out:
# X    1
# Y    2
# Z    3
# Name: type, dtype: int64

# %%
data2
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30  San Francisco
# 2  Charlie   22    Los Angeles
# 3    David   35        Chicago
# 4    Emily   28         Boston

# %%
data2.sort_values(by=['Age'],ascending=False)
# Out:
#       Name  Age           City
# 3    David   35        Chicago
# 1      Bob   30  San Francisco
# 4    Emily   28         Boston
# 0    Alice   25       New York
# 2  Charlie   22    Los Angeles

# %%
data2.sort_index(ascending=False)
# Out:
#       Name  Age           City
# 4    Emily   28         Boston
# 3    David   35        Chicago
# 2  Charlie   22    Los Angeles
# 1      Bob   30  San Francisco
# 0    Alice   25       New York

# %%
data2['Age'].nlargest(1)
# Out:
# 3    35
# Name: Age, dtype: int64

# %%
data2['Age'].nsmallest(1)
# Out:
# 2    22
# Name: Age, dtype: int64

# %%
data.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
data2.size
# Out:
# 15

# %%
s1=pd.Series([1,2,3])
s2=pd.Series([4,5,6])

# %%
s1.add(s2)
# Out:
# 0    5
# 1    7
# 2    9
# dtype: int64

# %%
s1.sub(s2)
# Out:
# 0   -3
# 1   -3
# 2   -3
# dtype: int64

# %%
s1.mul(s2)
# Out:
# 0     4
# 1    10
# 2    18
# dtype: int64

# %%
s1.div(s2)
# Out:
# 0    0.25
# 1    0.40
# 2    0.50
# dtype: float64

# %%
data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
data2['Age'].mean()
# Out:
# 28.0

# %%
data2['Age'].max()
# Out:
# 35

# %%
data2['Age'].min()
# Out:
# 22

# %%
data2['Age'].sum()
# Out:
# 140

# %%
data2['Age'].count()
# Out:
# 5

# %%
data2.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
data2.size
# Out:
# 15

# %%
data2.columns
# Out:
# Index(['Name', 'Age', 'City'], dtype='object')

# %%
data2.shape
# Out:
# (5, 3)

# %%
data2.empty
# Out:
# False

# %%
data2['Age'].is_monotonic_decreasing
# Out:
# False

# %%
data2['Age'].is_monotonic_increasing
# Out:
# False

# %%
data2['Age'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0    25
# 1    30
# 2    22
# 3    35
# 4    28
# Name: Age, dtype: int64>

# %%
data2['rolling']=data2['Age'].rolling(window=2).sum()

# %%
data2
# Out:
#       Name  Age           City  rolling
# 0    Alice   25       New York      NaN
# 1      Bob   30  San Francisco     55.0
# 2  Charlie   22    Los Angeles     52.0
# 3    David   35        Chicago     57.0
# 4    Emily   28         Boston     63.0

# %%
data2['expanding']=data2['Age'].expanding().sum()

# %%
data2
# Out:
#       Name  Age           City  rolling  expanding
# 0    Alice   25       New York      NaN       25.0
# 1      Bob   30  San Francisco     55.0       55.0
# 2  Charlie   22    Los Angeles     52.0       77.0
# 3    David   35        Chicago     57.0      112.0
# 4    Emily   28         Boston     63.0      140.0

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
data.groupby(['Item_Fat_Content','Outlet_Size'])['Item_MRP'].sum()
# Out:
# Item_Fat_Content  Outlet_Size
# LF                High             4453.4388
#                   Medium          14540.0508
#                   Small           13819.1604
# Low Fat           High            79513.5096
#                   Medium         231814.3150
#                   Small          201852.6250
# Regular           High            43855.6490
#                   Medium         135629.2168
#                   Small          116117.9858
# low fat           High             2435.1964
#                   Medium           4680.7082
#                   Small            3442.9886
# reg               High             1551.2218
#                   Medium           6005.0160
#                   Small            3792.0994
# Name: Item_MRP, dtype: float64

# %%
data.groupby(['Item_Fat_Content','Outlet_Size']).agg({'Item_MRP':'sum'})
# Out:
#                                  Item_MRP
# Item_Fat_Content Outlet_Size
# LF               High           4453.4388
#                  Medium        14540.0508
#                  Small         13819.1604
# Low Fat          High          79513.5096
#                  Medium       231814.3150
#                  Small        201852.6250
# Regular          High          43855.6490
#                  Medium       135629.2168
#                  Small        116117.9858
# low fat          High           2435.1964
#                  Medium         4680.7082
#                  Small          3442.9886
# reg              High           1551.2218
#                  Medium         6005.0160
#                  Small          3792.0994

# %%
data.groupby(['Item_Fat_Content','Outlet_Size']).agg({'Item_MRP':'sum','Item_Weight':['mean','sum']})
# Out:
#                                  Item_MRP Item_Weight
#                                       sum        mean        sum
# Item_Fat_Content Outlet_Size
# LF               High           4453.4388   13.849063    443.170
#                  Medium        14540.0508   13.012574    884.855
#                  Small         13819.1604   12.334156    949.730
# Low Fat          High          79513.5096   13.254847   7369.695
#                  Medium       231814.3150   13.000772  14391.855
#                  Small        201852.6250   12.963897  14402.890
# Regular          High          43855.6490   12.544281   3926.360
#                  Medium       135629.2168   12.717006   7986.280
#                  Small        116117.9858   12.730047   8070.850
# low fat          High           2435.1964   12.129722    218.335
#                  Medium         4680.7082   13.159211    250.025
#                  Small          3442.9886   11.253438    180.055
# ...

# %%
data2['Age'].rank(ascending=False)
# Out:
# 0    4.0
# 1    2.0
# 2    5.0
# 3    1.0
# 4    3.0
# Name: Age, dtype: float64
