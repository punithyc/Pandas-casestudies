# %%
import pandas as pd

# %%
data=pd.read_csv("C:\\Users\\punith yc\\Downloads\\Dataset New.csv")

# %%
data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
data.drop(columns=['Item_Identifier'])
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0           9.300          Low Fat         0.016047                  Dairy
# 1           5.920          Regular         0.019278            Soft Drinks
# 2          17.500          Low Fat         0.016760                   Meat
# 3          19.200          Regular         0.000000  Fruits and Vegetables
# 4           8.930          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8519        8.380          Regular         0.046982           Baking Goods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
data.drop([0])
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 1               Soft Drinks   48.2692            OUT018
# ...

# %%
data.drop([1,2,3])
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 7              FDP10          NaN          Low Fat         0.127470
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# ...

# %%
data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
data.drop([0])
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 1               Soft Drinks   48.2692            OUT018
# ...

# %%
data.drop([0],inplace=True)

# %%
data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 1               Soft Drinks   48.2692            OUT018
# ...

# %%
data.drop(columns='Item_Identifier',inplace=True)

# %%
data
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 1           5.920          Regular         0.019278            Soft Drinks
# 2          17.500          Low Fat         0.016760                   Meat
# 3          19.200          Regular         0.000000  Fruits and Vegetables
# 4           8.930          Low Fat         0.000000              Household
# 5          10.395          Regular         0.000000           Baking Goods
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8519        8.380          Regular         0.046982           Baking Goods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
data.head()
# Out:
#    Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 1        5.920          Regular         0.019278            Soft Drinks
# 2       17.500          Low Fat         0.016760                   Meat
# 3       19.200          Regular         0.000000  Fruits and Vegetables
# 4        8.930          Low Fat         0.000000              Household
# 5       10.395          Regular         0.000000           Baking Goods
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 1   48.2692            OUT018                       2009      Medium
# 2  141.6180            OUT049                       1999      Medium
# 3  182.0950            OUT010                       1998         NaN
# 4   53.8614            OUT013                       1987        High
# 5   51.4008            OUT018                       2009      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %%
data.tail()
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility           Item_Type  \
# 8518        6.865          Low Fat         0.056783         Snack Foods
# 8519        8.380          Regular         0.046982        Baking Goods
# 8520       10.600          Low Fat         0.035186  Health and Hygiene
# 8521        7.210          Regular         0.145221         Snack Foods
# 8522       14.800          Low Fat         0.044878         Soft Drinks
#
#       Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 8518  214.5218            OUT013                       1987        High
# 8519  108.1570            OUT045                       2002         NaN
# 8520   85.1224            OUT035                       2004       Small
# 8521  103.1332            OUT018                       2009      Medium
# 8522   75.4670            OUT046                       1997       Small
#
#      Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %%
data.columns
# Out:
# Index(['Item_Weight', 'Item_Fat_Content', 'Item_Visibility', 'Item_Type',
#        'Item_MRP', 'Outlet_Identifier', 'Outlet_Establishment_Year',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type',
#        'Item_Outlet_Sales'],
#       dtype='object')

# %%
data.shape
# Out:
# (8522, 11)

# %%
len(data)
# Out:
# 8522

# %%
len(data['Item_Weight'])
# Out:
# 8522

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8522 entries, 1 to 8522
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Weight                7059 non-null   float64
#  1   Item_Fat_Content           8522 non-null   object
#  2   Item_Visibility            8522 non-null   float64
#  3   Item_Type                  8522 non-null   object
#  4   Item_MRP                   8522 non-null   float64
#  5   Outlet_Identifier          8522 non-null   object
#  6   Outlet_Establishment_Year  8522 non-null   int64
#  7   Outlet_Size                6112 non-null   object
#  8   Outlet_Location_Type       8522 non-null   object
#  9   Outlet_Type                8522 non-null   object
#  10  Item_Outlet_Sales          8522 non-null   float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 732.5+ KB

# %%
data.describe(include='all')
# Out:
#         Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# count   7059.000000             8522      8522.000000                   8522
# unique          NaN                5              NaN                     16
# top             NaN          Low Fat              NaN  Fruits and Vegetables
# freq            NaN             5088              NaN                   1232
# mean      12.858149              NaN         0.066138                    NaN
# std        4.643592              NaN         0.051598                    NaN
# min        4.555000              NaN         0.000000                    NaN
# 25%        8.772500              NaN         0.027000                    NaN
# 50%       12.600000              NaN         0.053935                    NaN
# 75%       16.850000              NaN         0.094594                    NaN
# max       21.350000              NaN         0.328391                    NaN
#
# ...

# %%
data.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7059.000000      8522.000000  8522.000000                8522.000000
# mean     12.858149         0.066138   140.980013                1997.831730
# std       4.643592         0.051598    62.267562                   8.372242
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.772500         0.027000    93.817950                1987.000000
# 50%      12.600000         0.053935   142.979900                1999.000000
# 75%      16.850000         0.094594   185.625950                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8522.000000
# mean         2181.106580
# std          1706.516719
# min            33.290000
# 25%           833.914500
# 50%          1794.331000
# 75%          3100.963500
# max         13086.964800

# %%
data.describe(include=float)
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Item_Outlet_Sales
# count  7059.000000      8522.000000  8522.000000        8522.000000
# mean     12.858149         0.066138   140.980013        2181.106580
# std       4.643592         0.051598    62.267562        1706.516719
# min       4.555000         0.000000    31.290000          33.290000
# 25%       8.772500         0.027000    93.817950         833.914500
# 50%      12.600000         0.053935   142.979900        1794.331000
# 75%      16.850000         0.094594   185.625950        3100.963500
# max      21.350000         0.328391   266.888400       13086.964800

# %%
data.describe(include='object')
# Out:
#        Item_Fat_Content              Item_Type Outlet_Identifier Outlet_Size  \
# count              8522                   8522              8522        6112
# unique                5                     16                10           3
# top             Low Fat  Fruits and Vegetables            OUT027      Medium
# freq               5088                   1232               935        2792
#
#        Outlet_Location_Type        Outlet_Type
# count                  8522               8522
# unique                    3                  4
# top                  Tier 3  Supermarket Type1
# freq                   3350               5576

# %%
data.describe(include=int)
# Out:
#        Outlet_Establishment_Year
# count                8522.000000
# mean                 1997.831730
# std                     8.372242
# min                  1985.000000
# 25%                  1987.000000
# 50%                  1999.000000
# 75%                  2004.000000
# max                  2009.000000

# %%
data.describe(include=[int,float,object])
# Out:
#         Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# count   7059.000000             8522      8522.000000                   8522
# unique          NaN                5              NaN                     16
# top             NaN          Low Fat              NaN  Fruits and Vegetables
# freq            NaN             5088              NaN                   1232
# mean      12.858149              NaN         0.066138                    NaN
# std        4.643592              NaN         0.051598                    NaN
# min        4.555000              NaN         0.000000                    NaN
# 25%        8.772500              NaN         0.027000                    NaN
# 50%       12.600000              NaN         0.053935                    NaN
# 75%       16.850000              NaN         0.094594                    NaN
# max       21.350000              NaN         0.328391                    NaN
#
# ...

# %%
(data['Item_Outlet_Sales']>1000)& (data['Item_Visibility']=='Regular')
# Out:
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
#         ...
# 8518    False
# 8519    False
# 8520    False
# 8521    False
# 8522    False
# Length: 8522, dtype: bool

# %%
filt=data[(data['Item_Outlet_Sales']>2000)& (data['Item_Visibility']=='Low Fat')]

# %%
filt
# Out:
# Empty DataFrame
# Columns: [Item_Weight, Item_Fat_Content, Item_Visibility, Item_Type, Item_MRP, Outlet_Identifier, Outlet_Establishment_Year, Outlet_Size, Outlet_Location_Type, Outlet_Type, Item_Outlet_Sales]
# Index: []

# %%
name=input()
if name =='bob' or 'tom' or 'mike':
    print('granted')
else:
    print('denied')
# Out:
# granted

# %%
data.drop([1],inplace=True)

# %%
data
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 2          17.500          Low Fat         0.016760                   Meat
# 3          19.200          Regular         0.000000  Fruits and Vegetables
# 4           8.930          Low Fat         0.000000              Household
# 5          10.395          Regular         0.000000           Baking Goods
# 6          13.650          Regular         0.012741            Snack Foods
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8519        8.380          Regular         0.046982           Baking Goods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
data.sort_values('Outlet_Size',ascending=False)
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 4294        19.20          Low Fat         0.041228              Household
# 4450        17.60          Low Fat         0.058091                   Meat
# 4456        17.25          Low Fat         0.107021           Frozen Foods
# 4459         7.50          Low Fat         0.036228     Health and Hygiene
# 4462          NaN          Low Fat         0.106908              Breakfast
# ...           ...              ...              ...                    ...
# 8502         8.42          Low Fat         0.070712              Household
# 8508        11.35          Regular         0.043246  Fruits and Vegetables
# 8509         8.10          Low Fat         0.214306  Fruits and Vegetables
# 8514        15.00          Regular         0.054489                 Canned
# 8519         8.38          Regular         0.046982           Baking Goods
#
# ...

# %%
data.sort_values(['Item_Weight','Outlet_Size'],ascending=False)
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 2368        21.35          Low Fat         0.068809                 Canned
# 4468        21.35          Low Fat         0.068822                 Canned
# 43          21.35          Low Fat         0.069103                 Canned
# 6389        21.35          Low Fat         0.078061  Fruits and Vegetables
# 2802        21.35          Low Fat         0.068765                 Canned
# ...           ...              ...              ...                    ...
# 8472          NaN          Low Fat         0.053185     Health and Hygiene
# 8485          NaN          Low Fat         0.043792            Soft Drinks
# 8487          NaN          Low Fat         0.037006            Soft Drinks
# 8488          NaN          Low Fat         0.091473                 Others
# 8504          NaN          Low Fat         0.124111              Household
#
# ...

# %%
data.isnull().sum()
# Out:
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
len(data)
# Out:
# 4648

# %%
data
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 2          17.500          Low Fat         0.016760                   Meat
# 4           8.930          Low Fat         0.000000              Household
# 5          10.395          Regular         0.000000           Baking Goods
# 6          13.650          Regular         0.012741            Snack Foods
# 10         11.800          Low Fat         0.000000  Fruits and Vegetables
# ...           ...              ...              ...                    ...
# 8517       20.750              reg         0.083607           Frozen Foods
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
data.loc[[4,10,11]]
# Out:
#     Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 4          8.93          Low Fat         0.000000              Household
# 10        11.80          Low Fat         0.000000  Fruits and Vegetables
# 11        18.50          Regular         0.045464                  Dairy
#
#     Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 4    53.8614            OUT013                       1987        High
# 10   45.5402            OUT049                       1999      Medium
# 11  144.1102            OUT046                       1997       Small
#
#    Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 4                Tier 3  Supermarket Type1           994.7052
# 10               Tier 1  Supermarket Type1          1516.0266
# 11               Tier 1  Supermarket Type1          2187.1530

# %%
data.loc[10:20]
# Out:
#     Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 10        11.80          Low Fat         0.000000  Fruits and Vegetables
# 11        18.50          Regular         0.045464                  Dairy
# 12        15.10          Regular         0.100014  Fruits and Vegetables
# 13        17.60          Regular         0.047257            Snack Foods
# 14        16.35          Low Fat         0.068024  Fruits and Vegetables
# 15         9.00          Regular         0.069089              Breakfast
# 16        11.80          Low Fat         0.008596     Health and Hygiene
# 17         9.00          Regular         0.069196              Breakfast
# 19        13.35          Low Fat         0.102492                  Dairy
# 20        18.85          Regular         0.138190            Snack Foods
#
#     Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 10   45.5402            OUT049                       1999      Medium
# ...

# %%
data.iloc[10]
# Out:
# Item_Weight                                11.8
# Item_Fat_Content                        Low Fat
# Item_Visibility                        0.008596
# Item_Type                    Health and Hygiene
# Item_MRP                               115.3492
# Outlet_Identifier                        OUT018
# Outlet_Establishment_Year                  2009
# Outlet_Size                              Medium
# Outlet_Location_Type                     Tier 3
# Outlet_Type                   Supermarket Type2
# Item_Outlet_Sales                     1621.8888
# Name: 16, dtype: object

# %%
data1=[1,2,3,4]
data2=[5,6,7,8]

# %%
pd.Series(data1)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
pd.Series(data2)
# Out:
# 0    5
# 1    6
# 2    7
# 3    8
# dtype: int64

# %%
data1>data2
# Out:
# False

# %%
data1==data2
# Out:
# False

# %%
data1<data2
# Out:
# True

# %%
data['Item_MRP'].mean()
# Out:
# 141.71317689328743

# %%
data['Item_MRP'].count()
# Out:
# 4648

# %%
data['Item_MRP'].max()
# Out:
# 266.8884

# %%
data['Item_MRP'].min()
# Out:
# 31.49

# %%
data
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 2          17.500          Low Fat         0.016760                   Meat
# 4           8.930          Low Fat         0.000000              Household
# 5          10.395          Regular         0.000000           Baking Goods
# 6          13.650          Regular         0.012741            Snack Foods
# 10         11.800          Low Fat         0.000000  Fruits and Vegetables
# ...           ...              ...              ...                    ...
# 8517       20.750              reg         0.083607           Frozen Foods
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
data.columns
# Out:
# Index(['Item_Weight', 'Item_Fat_Content', 'Item_Visibility', 'Item_Type',
#        'Item_MRP', 'Outlet_Identifier', 'Outlet_Establishment_Year',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type',
#        'Item_Outlet_Sales'],
#       dtype='object')

# %%
data.size
# Out:
# 51128

# %%
data.shape
# Out:
# (4648, 11)

# %%
data['Outlet_Establishment_Year'].is_monotonic_decreasing
# Out:
# False

# %%
data['Outlet_Size'].is_monotonic_increasing
# Out:
# False

# %%
data['Item_Type'].unique()
# Out:
# array(['Meat', 'Household', 'Baking Goods', 'Snack Foods',
#        'Fruits and Vegetables', 'Dairy', 'Breakfast',
#        'Health and Hygiene', 'Frozen Foods', 'Hard Drinks', 'Soft Drinks',
#        'Canned', 'Starchy Foods', 'Breads', 'Others', 'Seafood'],
#       dtype=object)

# %%
data['Outlet_Establishment_Year'].mean()
# Out:
# 1999.1884681583476

# %%
data['Outlet_Establishment_Year'].sum()
# Out:
# 9292228

# %%
data['Outlet_Establishment_Year'].max()
# Out:
# 2009

# %%
data['Outlet_Establishment_Year'].min()
# Out:
# 1987

# %%
data['Outlet_Establishment_Year'].count()
# Out:
# 4648

# %%
data['Outlet_Establishment_Year'].is_unique
# Out:
# False

# %%
data['Outlet_Size'].is_unique
# Out:
# False

# %%
data1=[1,2,3,4,5]

# %%
pd.DataFrame(data1,columns=['jksdsfdbj'])
# Out:
#    jksdsfdbj
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5

# %%
data2=[6,7,89,9,90]

# %%
pd.Series(data2,index=['f','d','d','d','f'],name='ndffkjv')
# Out:
# f     6
# d     7
# d    89
# d     9
# f    90
# Name: ndffkjv, dtype: int64

# %%
data3={'name':['d','d','g','g','g']}

# %%
data4=pd.DataFrame(data3,index=['d','f','f','h','j'])

# %%
data4['marks']=[10,20,30,40,50]

# %%
data4
# Out:
#   name  marks
# d    d     10
# f    d     20
# f    g     30
# h    g     40
# j    g     50

# %%
data4.loc['h']
# Out:
# name      g
# marks    40
# Name: h, dtype: object

# %%
gh={'name':'h','marks':'none'}

# %%
data4.loc['i']=gh

# %%
data4
# Out:
#   name marks
# d    d    10
# f    d    20
# f    g    30
# h    g    40
# j    g    50
# i    h  none

# %%
data4.loc['h']
# Out:
# name      g
# marks    40
# Name: h, dtype: object

# %%
data4.fillna(60)
# Out:
#   name marks
# d    d    10
# f    d    20
# f    g    30
# h    g    40
# j    g    50
# i    h  none

# %%
data4
# Out:
#   name marks
# d    d    10
# f    d    20
# f    g    30
# h    g    40
# j    g    50
# i    h  none

# %%
data4.fillna('40')
# Out:
#   name marks
# d    d    10
# f    d    20
# f    g    30
# h    g    40
# j    g    50
# i    h  none

# %% [markdown]
# ####

# %%
data4.dropna(inplace=True)

# %%
data4
# Out:
#   name marks
# d    d    10
# f    d    20
# f    g    30
# h    g    40
# j    g    50
# i    h  none

# %%
data5={'FellowShipId':[1001,1002,1003,1004],'FirstName':['Frodo','Samwise','Gandalf','Pippin'],'Skills':['Hiding','Gardening','Spells','Fireworks']}

# %%
d1=pd.DataFrame(data5)

# %%
d1
# Out:
#    FellowShipId FirstName     Skills
# 0          1001     Frodo     Hiding
# 1          1002   Samwise  Gardening
# 2          1003   Gandalf     Spells
# 3          1004    Pippin  Fireworks

# %%
data7={'FellowShipId':[1001,1002,1006,1007,1008],'FirstName':['Frodo','Samwise','Legolas','Elrond','Barromir'],'agee':[50,39,2931,6520,51] }

# %%
d2=pd.DataFrame(data7)

# %%
d2
# Out:
#    FellowShipId FirstName  agee
# 0          1001     Frodo    50
# 1          1002   Samwise    39
# 2          1006   Legolas  2931
# 3          1007    Elrond  6520
# 4          1008  Barromir    51

# %%
d1.merge(d2)
# Out:
#    FellowShipId FirstName     Skills  agee
# 0          1001     Frodo     Hiding    50
# 1          1002   Samwise  Gardening    39

# %%
d1.merge(d2,how='inner',on='FellowShipId')
# Out:
#    FellowShipId FirstName_x     Skills FirstName_y  agee
# 0          1001       Frodo     Hiding       Frodo    50
# 1          1002     Samwise  Gardening     Samwise    39

# %%
d1.merge(d2,how='left',on='FellowShipId')
# Out:
#    FellowShipId FirstName_x     Skills FirstName_y  agee
# 0          1001       Frodo     Hiding       Frodo  50.0
# 1          1002     Samwise  Gardening     Samwise  39.0
# 2          1003     Gandalf     Spells         NaN   NaN
# 3          1004      Pippin  Fireworks         NaN   NaN

# %%
d1.merge(d2,how='outer',on='FellowShipId')
# Out:
#    FellowShipId FirstName_x     Skills FirstName_y    agee
# 0          1001       Frodo     Hiding       Frodo    50.0
# 1          1002     Samwise  Gardening     Samwise    39.0
# 2          1003     Gandalf     Spells         NaN     NaN
# 3          1004      Pippin  Fireworks         NaN     NaN
# 4          1006         NaN        NaN     Legolas  2931.0
# 5          1007         NaN        NaN      Elrond  6520.0
# 6          1008         NaN        NaN    Barromir    51.0

# %%
d1.merge(d2,how='right',on='FellowShipId')
# Out:
#    FellowShipId FirstName_x     Skills FirstName_y  agee
# 0          1001       Frodo     Hiding       Frodo    50
# 1          1002     Samwise  Gardening     Samwise    39
# 2          1006         NaN        NaN     Legolas  2931
# 3          1007         NaN        NaN      Elrond  6520
# 4          1008         NaN        NaN    Barromir    51

# %%
d1.join(d2,on='FellowShipId',how='outer',lsuffix='_left',rsuffix='_right')
# Out:
#      FellowShipId  FellowShipId_left FirstName_left     Skills  \
# 0.0          1001             1001.0          Frodo     Hiding
# 1.0          1002             1002.0        Samwise  Gardening
# 2.0          1003             1003.0        Gandalf     Spells
# 3.0          1004             1004.0         Pippin  Fireworks
# NaN             0                NaN            NaN        NaN
# NaN             1                NaN            NaN        NaN
# NaN             2                NaN            NaN        NaN
# NaN             3                NaN            NaN        NaN
# NaN             4                NaN            NaN        NaN
#
#      FellowShipId_right FirstName_right    agee
# 0.0                 NaN             NaN     NaN
# 1.0                 NaN             NaN     NaN
# 2.0                 NaN             NaN     NaN
# 3.0                 NaN             NaN     NaN
# NaN              1001.0           Frodo    50.0
# ...

# %%
pd.concat([d1,d2])
# Out:
#    FellowShipId FirstName     Skills    agee
# 0          1001     Frodo     Hiding     NaN
# 1          1002   Samwise  Gardening     NaN
# 2          1003   Gandalf     Spells     NaN
# 3          1004    Pippin  Fireworks     NaN
# 0          1001     Frodo        NaN    50.0
# 1          1002   Samwise        NaN    39.0
# 2          1006   Legolas        NaN  2931.0
# 3          1007    Elrond        NaN  6520.0
# 4          1008  Barromir        NaN    51.0

# %%
d3=pd.concat([d1,d2])

# %%
d1.sort_values(by='FellowShipId',ascending=False)
# Out:
#    FellowShipId FirstName     Skills
# 3          1004    Pippin  Fireworks
# 2          1003   Gandalf     Spells
# 1          1002   Samwise  Gardening
# 0          1001     Frodo     Hiding

# %%
d2.sort_values(by='agee',ascending=True)
# Out:
#    FellowShipId FirstName  agee
# 1          1002   Samwise    39
# 0          1001     Frodo    50
# 4          1008  Barromir    51
# 2          1006   Legolas  2931
# 3          1007    Elrond  6520

# %%
d3.dropna(inplace=True)

# %%
d3
# Out:
# Empty DataFrame
# Columns: [FellowShipId, FirstName, Skills, agee]
# Index: []

# %%
d3.fillna(0)
# Out:
# Empty DataFrame
# Columns: [FellowShipId, FirstName, Skills, agee]
# Index: []

# %%
d2['agee'].median()
# Out:
# 51.0

# %%
d2
# Out:
#    FellowShipId FirstName  agee
# 0          1001     Frodo    50
# 1          1002   Samwise    39
# 2          1006   Legolas  2931
# 3          1007    Elrond  6520
# 4          1008  Barromir    51

# %%
d2['agee'].std()
# Out:
# 2859.6471285807274

# %%
d2['agee'].var()
# Out:
# 8177581.7

# %%
d2.rename(columns={'FellowShipID':'Id'},inplace=True)

# %%
d2
# Out:
#    FellowShipId FirstName  agee
# 0          1001     Frodo    50
# 1          1002   Samwise    39
# 2          1006   Legolas  2931
# 3          1007    Elrond  6520
# 4          1008  Barromir    51

# %%
data.rename(columns={'Item_Weight':'Weight'},inplace=True)

# %%
data
# Out:
#       Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 2     17.500          Low Fat         0.016760                   Meat
# 4      8.930          Low Fat         0.000000              Household
# 5     10.395          Regular         0.000000           Baking Goods
# 6     13.650          Regular         0.012741            Snack Foods
# 10    11.800          Low Fat         0.000000  Fruits and Vegetables
# ...      ...              ...              ...                    ...
# 8517  20.750              reg         0.083607           Frozen Foods
# 8518   6.865          Low Fat         0.056783            Snack Foods
# 8520  10.600          Low Fat         0.035186     Health and Hygiene
# 8521   7.210          Regular         0.145221            Snack Foods
# 8522  14.800          Low Fat         0.044878            Soft Drinks
#
#       Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# ...

# %%
data
# Out:
#       Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 2     17.500          Low Fat         0.016760                   Meat
# 4      8.930          Low Fat         0.000000              Household
# 5     10.395          Regular         0.000000           Baking Goods
# 6     13.650          Regular         0.012741            Snack Foods
# 10    11.800          Low Fat         0.000000  Fruits and Vegetables
# ...      ...              ...              ...                    ...
# 8517  20.750              reg         0.083607           Frozen Foods
# 8518   6.865          Low Fat         0.056783            Snack Foods
# 8520  10.600          Low Fat         0.035186     Health and Hygiene
# 8521   7.210          Regular         0.145221            Snack Foods
# 8522  14.800          Low Fat         0.044878            Soft Drinks
#
#       Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# ...

# %%
data.rename(columns={'Weight':'Item_Weight'},inplace=True)

# %%
data
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 2          17.500          Low Fat         0.016760                   Meat
# 4           8.930          Low Fat         0.000000              Household
# 5          10.395          Regular         0.000000           Baking Goods
# 6          13.650          Regular         0.012741            Snack Foods
# 10         11.800          Low Fat         0.000000  Fruits and Vegetables
# ...           ...              ...              ...                    ...
# 8517       20.750              reg         0.083607           Frozen Foods
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
data
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 2          17.500          Low Fat         0.016760                   Meat
# 4           8.930          Low Fat         0.000000              Household
# 5          10.395          Regular         0.000000           Baking Goods
# 6          13.650          Regular         0.012741            Snack Foods
# 10         11.800          Low Fat         0.000000  Fruits and Vegetables
# ...           ...              ...              ...                    ...
# 8517       20.750              reg         0.083607           Frozen Foods
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
data.iloc[2]
# Out:
# Item_Weight                             10.395
# Item_Fat_Content                       Regular
# Item_Visibility                            0.0
# Item_Type                         Baking Goods
# Item_MRP                               51.4008
# Outlet_Identifier                       OUT018
# Outlet_Establishment_Year                 2009
# Outlet_Size                             Medium
# Outlet_Location_Type                    Tier 3
# Outlet_Type                  Supermarket Type2
# Item_Outlet_Sales                     556.6088
# Name: 5, dtype: object

# %%
data.rename(index={2:"two"},inplace=True)

# %%
data
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# two        17.500          Low Fat         0.016760                   Meat
# 4           8.930          Low Fat         0.000000              Household
# 5          10.395          Regular         0.000000           Baking Goods
# 6          13.650          Regular         0.012741            Snack Foods
# 10         11.800          Low Fat         0.000000  Fruits and Vegetables
# ...           ...              ...              ...                    ...
# 8517       20.750              reg         0.083607           Frozen Foods
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
data.rename(index={'two':2},inplace=True)

# %%
data
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 2          17.500          Low Fat         0.016760                   Meat
# 4           8.930          Low Fat         0.000000              Household
# 5          10.395          Regular         0.000000           Baking Goods
# 6          13.650          Regular         0.012741            Snack Foods
# 10         11.800          Low Fat         0.000000  Fruits and Vegetables
# ...           ...              ...              ...                    ...
# 8517       20.750              reg         0.083607           Frozen Foods
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
d2
# Out:
#    FellowShipId FirstName  agee
# 0          1001     Frodo    50
# 1          1002   Samwise    39
# 2          1006   Legolas  2931
# 3          1007    Elrond  6520
# 4          1008  Barromir    51

# %%
d1
# Out:
#    FellowShipId FirstName     Skills
# 0          1001     Frodo     Hiding
# 1          1002   Samwise  Gardening
# 2          1003   Gandalf     Spells
# 3          1004    Pippin  Fireworks

# %%
pd.concat([d1,d2])
# Out:
#    FellowShipId FirstName     Skills    agee
# 0          1001     Frodo     Hiding     NaN
# 1          1002   Samwise  Gardening     NaN
# 2          1003   Gandalf     Spells     NaN
# 3          1004    Pippin  Fireworks     NaN
# 0          1001     Frodo        NaN    50.0
# 1          1002   Samwise        NaN    39.0
# 2          1006   Legolas        NaN  2931.0
# 3          1007    Elrond        NaN  6520.0
# 4          1008  Barromir        NaN    51.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4648 entries, 2 to 8522
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Weight                4648 non-null   float64
#  1   Item_Fat_Content           4648 non-null   object
#  2   Item_Visibility            4648 non-null   float64
#  3   Item_Type                  4648 non-null   object
#  4   Item_MRP                   4648 non-null   float64
#  5   Outlet_Identifier          4648 non-null   object
#  6   Outlet_Establishment_Year  4648 non-null   int64
#  7   Outlet_Size                4648 non-null   object
#  8   Outlet_Location_Type       4648 non-null   object
#  9   Outlet_Type                4648 non-null   object
#  10  Item_Outlet_Sales          4648 non-null   float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 435.8+ KB

# %%
data['Outlet_Establishment_Year']=str(data['Outlet_Establishment_Year'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4648 entries, 2 to 8522
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Weight                4648 non-null   float64
#  1   Item_Fat_Content           4648 non-null   object
#  2   Item_Visibility            4648 non-null   float64
#  3   Item_Type                  4648 non-null   object
#  4   Item_MRP                   4648 non-null   float64
#  5   Outlet_Identifier          4648 non-null   object
#  6   Outlet_Establishment_Year  4648 non-null   object
#  7   Outlet_Size                4648 non-null   object
#  8   Outlet_Location_Type       4648 non-null   object
#  9   Outlet_Type                4648 non-null   object
#  10  Item_Outlet_Sales          4648 non-null   float64
# dtypes: float64(4), object(7)
# memory usage: 435.8+ KB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4648 entries, 2 to 8522
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Weight                4648 non-null   float64
#  1   Item_Fat_Content           4648 non-null   object
#  2   Item_Visibility            4648 non-null   float64
#  3   Item_Type                  4648 non-null   object
#  4   Item_MRP                   4648 non-null   float64
#  5   Outlet_Identifier          4648 non-null   object
#  6   Outlet_Establishment_Year  4648 non-null   object
#  7   Outlet_Size                4648 non-null   object
#  8   Outlet_Location_Type       4648 non-null   object
#  9   Outlet_Type                4648 non-null   object
#  10  Item_Outlet_Sales          4648 non-null   float64
# dtypes: float64(4), object(7)
# memory usage: 435.8+ KB

# %%
data.Outlet_Establishment_Year.astype('object')
# Out:
# 2       2       1999\n4       1987\n5       2009\n6   ...
# 4       2       1999\n4       1987\n5       2009\n6   ...
# 5       2       1999\n4       1987\n5       2009\n6   ...
# 6       2       1999\n4       1987\n5       2009\n6   ...
# 10      2       1999\n4       1987\n5       2009\n6   ...
#                               ...
# 8517    2       1999\n4       1987\n5       2009\n6   ...
# 8518    2       1999\n4       1987\n5       2009\n6   ...
# 8520    2       1999\n4       1987\n5       2009\n6   ...
# 8521    2       1999\n4       1987\n5       2009\n6   ...
# 8522    2       1999\n4       1987\n5       2009\n6   ...
# Name: Outlet_Establishment_Year, Length: 4648, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4648 entries, 2 to 8522
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Weight                4648 non-null   float64
#  1   Item_Fat_Content           4648 non-null   object
#  2   Item_Visibility            4648 non-null   float64
#  3   Item_Type                  4648 non-null   object
#  4   Item_MRP                   4648 non-null   float64
#  5   Outlet_Identifier          4648 non-null   object
#  6   Outlet_Establishment_Year  4648 non-null   object
#  7   Outlet_Size                4648 non-null   object
#  8   Outlet_Location_Type       4648 non-null   object
#  9   Outlet_Type                4648 non-null   object
#  10  Item_Outlet_Sales          4648 non-null   float64
# dtypes: float64(4), object(7)
# memory usage: 435.8+ KB

# %%
d2
# Out:
#    FellowShipId FirstName  agee
# 0          1001     Frodo    50
# 1          1002   Samwise    39
# 2          1006   Legolas  2931
# 3          1007    Elrond  6520
# 4          1008  Barromir    51

# %%
d2.replace('Frodo','ggvhsdf',inplace=True)

# %%
d2
# Out:
#    FellowShipId FirstName  agee
# 0          1001   ggvhsdf    50
# 1          1002   Samwise    39
# 2          1006   Legolas  2931
# 3          1007    Elrond  6520
# 4          1008  Barromir    51

# %%
d2
# Out:
#    FellowShipId FirstName  agee
# 0          1001   ggvhsdf    50
# 1          1002   Samwise    39
# 2          1006   Legolas  2931
# 3          1007    Elrond  6520
# 4          1008  Barromir    51

# %%
d2.replace('ggvhsdf','Frodo',inplace=True)

# %%
d2
# Out:
#    FellowShipId FirstName  agee
# 0          1001     Frodo    50
# 1          1002   Samwise    39
# 2          1006   Legolas  2931
# 3          1007    Elrond  6520
# 4          1008  Barromir    51

# %%
d2.FirstName.str.lower()
# Out:
# 0       frodo
# 1     samwise
# 2     legolas
# 3      elrond
# 4    barromir
# Name: FirstName, dtype: object

# %%
data['Item_Fat_Content'].str.lower()
# Out:
# 2       low fat
# 4       low fat
# 5       regular
# 6       regular
# 10      low fat
#          ...
# 8517        reg
# 8518    low fat
# 8520    low fat
# 8521    regular
# 8522    low fat
# Name: Item_Fat_Content, Length: 4648, dtype: object

# %%
data['Item_Fat_Content'].str.upper()
# Out:
# 2       LOW FAT
# 4       LOW FAT
# 5       REGULAR
# 6       REGULAR
# 10      LOW FAT
#          ...
# 8517        REG
# 8518    LOW FAT
# 8520    LOW FAT
# 8521    REGULAR
# 8522    LOW FAT
# Name: Item_Fat_Content, Length: 4648, dtype: object

# %%
data['Item_Fat_Content'].str.title()
# Out:
# 2       Low Fat
# 4       Low Fat
# 5       Regular
# 6       Regular
# 10      Low Fat
#          ...
# 8517        Reg
# 8518    Low Fat
# 8520    Low Fat
# 8521    Regular
# 8522    Low Fat
# Name: Item_Fat_Content, Length: 4648, dtype: object

# %%
data['Item_Fat_Content'].str.capitalize()
# Out:
# 2       Low fat
# 4       Low fat
# 5       Regular
# 6       Regular
# 10      Low fat
#          ...
# 8517        Reg
# 8518    Low fat
# 8520    Low fat
# 8521    Regular
# 8522    Low fat
# Name: Item_Fat_Content, Length: 4648, dtype: object

# %%
data['Item_Fat_Content'].str.title()
# Out:
# 2       Low Fat
# 4       Low Fat
# 5       Regular
# 6       Regular
# 10      Low Fat
#          ...
# 8517        Reg
# 8518    Low Fat
# 8520    Low Fat
# 8521    Regular
# 8522    Low Fat
# Name: Item_Fat_Content, Length: 4648, dtype: object

# %%
data['Item_Fat_Content'].str.strip()
# Out:
# 2       Low Fat
# 4       Low Fat
# 5       Regular
# 6       Regular
# 10      Low Fat
#          ...
# 8517        reg
# 8518    Low Fat
# 8520    Low Fat
# 8521    Regular
# 8522    Low Fat
# Name: Item_Fat_Content, Length: 4648, dtype: object

# %%
data['Item_Fat_Content'].str.lstrip()
# Out:
# 2       Low Fat
# 4       Low Fat
# 5       Regular
# 6       Regular
# 10      Low Fat
#          ...
# 8517        reg
# 8518    Low Fat
# 8520    Low Fat
# 8521    Regular
# 8522    Low Fat
# Name: Item_Fat_Content, Length: 4648, dtype: object

# %%
data['Item_Fat_Content'].str.rstrip()
# Out:
# 2       Low Fat
# 4       Low Fat
# 5       Regular
# 6       Regular
# 10      Low Fat
#          ...
# 8517        reg
# 8518    Low Fat
# 8520    Low Fat
# 8521    Regular
# 8522    Low Fat
# Name: Item_Fat_Content, Length: 4648, dtype: object

# %%
data['Item_Fat_Content'].str.rfind('regular')
# Out:
# 2      -1
# 4      -1
# 5      -1
# 6      -1
# 10     -1
#        ..
# 8517   -1
# 8518   -1
# 8520   -1
# 8521   -1
# 8522   -1
# Name: Item_Fat_Content, Length: 4648, dtype: int64

# %%
data['Item_Fat_Content'].str.count('e').sum()
# Out:
# 1645

# %%
data['Item_Fat_Content'].str.len()
# Out:
# 2       7
# 4       7
# 5       7
# 6       7
# 10      7
#        ..
# 8517    3
# 8518    7
# 8520    7
# 8521    7
# 8522    7
# Name: Item_Fat_Content, Length: 4648, dtype: int64

# %%
data['Item_Fat_Content'].str.swapcase()
# Out:
# 2       lOW fAT
# 4       lOW fAT
# 5       rEGULAR
# 6       rEGULAR
# 10      lOW fAT
#          ...
# 8517        REG
# 8518    lOW fAT
# 8520    lOW fAT
# 8521    rEGULAR
# 8522    lOW fAT
# Name: Item_Fat_Content, Length: 4648, dtype: object

# %%
data['Item_Fat_Content'].str.startswith('L').sum()
# Out:
# 2950

# %%
data['Item_Fat_Content'].str.endswith('r').sum()
# Out:
# 1574

# %%
data['Item_Fat_Content'].str.lower().str.contains('regular').sum()
# Out:
# 1574

# %%
data['Item_Fat_Content'].str.find('e').sum()
# Out:
# -1358

# %%
data
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 2          17.500          Low Fat         0.016760                   Meat
# 4           8.930          Low Fat         0.000000              Household
# 5          10.395          Regular         0.000000           Baking Goods
# 6          13.650          Regular         0.012741            Snack Foods
# 10         11.800          Low Fat         0.000000  Fruits and Vegetables
# ...           ...              ...              ...                    ...
# 8517       20.750              reg         0.083607           Frozen Foods
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
#       Item_MRP Outlet_Identifier  \
# ...

# %%
d2
# Out:
#    FellowShipId FirstName  agee
# 0          1001     Frodo    50
# 1          1002   Samwise    39
# 2          1006   Legolas  2931
# 3          1007    Elrond  6520
# 4          1008  Barromir    51

# %%
d2['agee_mean']=d2['agee'].rolling(len(d2.agee)).min()

# %%
d2
# Out:
#    FellowShipId FirstName  agee  agee_mean
# 0          1001     Frodo    50        NaN
# 1          1002   Samwise    39        NaN
# 2          1006   Legolas  2931        NaN
# 3          1007    Elrond  6520        NaN
# 4          1008  Barromir    51       39.0

# %%
my_list=[1,4,5,6,7,8,9,4,3,2,11,10]
sm=0
for i in range(len(my_list)):
    sm=sm+my_list[i]
    mn=sm/len(my_list)
print(mn)
# Out:
# 5.833333333333333

# %%
my_list=[1,4,5,6,7,8,9,4,3,2]

for i in range(len(my_list)):
    print(my_list[i])
# Out:
# 1
# 4
# 5
# 6
# 7
# 8
# 9
# 4
# 3
# 2

# %%
d2.drop(columns=['agee_mean'],inplace=True)

# %%
expanding_column=d2['agee'].expanding()

# %%
d2['cummulative_age']=expanding_column.sum()

# %%
d2
# Out:
#    FellowShipId FirstName  agee  cummulative_age
# 0          1001     Frodo    50             50.0
# 1          1002   Samwise    39             89.0
# 2          1006   Legolas  2931           3020.0
# 3          1007    Elrond  6520           9540.0
# 4          1008  Barromir    51           9591.0

# %%
expand_column=d2['agee'].expanding()

# %%
d2['mean_age']=expand_column.mean()

# %%
d2
# Out:
#    FellowShipId FirstName  agee  cummulative_age     mean_age
# 0          1001     Frodo    50             50.0    50.000000
# 1          1002   Samwise    39             89.0    44.500000
# 2          1006   Legolas  2931           3020.0  1006.666667
# 3          1007    Elrond  6520           9540.0  2385.000000
# 4          1008  Barromir    51           9591.0  1918.200000

# %%
ex_col=d2['agee'].expanding()

# %%
d2['min_age']=ex_col.min()

# %%
d2
# Out:
#    FellowShipId FirstName  agee  cummulative_age     mean_age  min_age
# 0          1001     Frodo    50             50.0    50.000000     50.0
# 1          1002   Samwise    39             89.0    44.500000     39.0
# 2          1006   Legolas  2931           3020.0  1006.666667     39.0
# 3          1007    Elrond  6520           9540.0  2385.000000     39.0
# 4          1008  Barromir    51           9591.0  1918.200000     39.0

# %%
exx_col=d2['agee'].expanding()

# %%
d2['max_age']=exx_col.max()

# %%
d2
# Out:
#    FellowShipId FirstName  agee  cummulative_age     mean_age  min_age  \
# 0          1001     Frodo    50             50.0    50.000000     50.0
# 1          1002   Samwise    39             89.0    44.500000     39.0
# 2          1006   Legolas  2931           3020.0  1006.666667     39.0
# 3          1007    Elrond  6520           9540.0  2385.000000     39.0
# 4          1008  Barromir    51           9591.0  1918.200000     39.0
#
#    max_age
# 0     50.0
# 1     50.0
# 2   2931.0
# 3   6520.0
# 4   6520.0

# %%
e_col=d2['agee'].expanding()

# %%
d2['std_age']=e_col.std()

# %%
d2
# Out:
#    FellowShipId FirstName  agee  cummulative_age     mean_age  min_age  \
# 0          1001     Frodo    50             50.0    50.000000     50.0
# 1          1002   Samwise    39             89.0    44.500000     39.0
# 2          1006   Legolas  2931           3020.0  1006.666667     39.0
# 3          1007    Elrond  6520           9540.0  2385.000000     39.0
# 4          1008  Barromir    51           9591.0  1918.200000     39.0
#
#    max_age      std_age
# 0     50.0          NaN
# 1     50.0     7.778175
# 2   2931.0  1666.530628
# 3   6520.0  3074.208950
# 4   6520.0  2859.647129

# %%
d2['agee'].rolling(2).sum()
# Out:
# 0       NaN
# 1      89.0
# 2    2970.0
# 3    9451.0
# 4    6571.0
# Name: agee, dtype: float64

# %%
expected_col3=d2['agee'].expanding()

# %%
d2['expec']=expected_col3.sum()

# %%
d2
# Out:
#    FellowShipId FirstName  agee  cummulative_age     mean_age  min_age  \
# 0          1001     Frodo    50             50.0    50.000000     50.0
# 1          1002   Samwise    39             89.0    44.500000     39.0
# 2          1006   Legolas  2931           3020.0  1006.666667     39.0
# 3          1007    Elrond  6520           9540.0  2385.000000     39.0
# 4          1008  Barromir    51           9591.0  1918.200000     39.0
#
#    max_age      std_age   expec
# 0     50.0          NaN    50.0
# 1     50.0     7.778175    89.0
# 2   2931.0  1666.530628  3020.0
# 3   6520.0  3074.208950  9540.0
# 4   6520.0  2859.647129  9591.0

# %%
exc_col=d2['agee'].expanding()

# %%
d2['exc']=exc_col.mean()

# %%
d2
# Out:
#    FellowShipId FirstName  agee  cummulative_age     mean_age  min_age  \
# 0          1001     Frodo    50             50.0    50.000000     50.0
# 1          1002   Samwise    39             89.0    44.500000     39.0
# 2          1006   Legolas  2931           3020.0  1006.666667     39.0
# 3          1007    Elrond  6520           9540.0  2385.000000     39.0
# 4          1008  Barromir    51           9591.0  1918.200000     39.0
#
#    max_age      std_age   expec          exc
# 0     50.0          NaN    50.0    50.000000
# 1     50.0     7.778175    89.0    44.500000
# 2   2931.0  1666.530628  3020.0  1006.666667
# 3   6520.0  3074.208950  9540.0  2385.000000
# 4   6520.0  2859.647129  9591.0  1918.200000

# %%
d2['ageee']=d2['agee'].rolling(2).sum()

# %%
d2
# Out:
#    FellowShipId FirstName  agee  cummulative_age     mean_age  min_age  \
# 0          1001     Frodo    50             50.0    50.000000     50.0
# 1          1002   Samwise    39             89.0    44.500000     39.0
# 2          1006   Legolas  2931           3020.0  1006.666667     39.0
# 3          1007    Elrond  6520           9540.0  2385.000000     39.0
# 4          1008  Barromir    51           9591.0  1918.200000     39.0
#
#    max_age      std_age   expec          exc   ageee
# 0     50.0          NaN    50.0    50.000000     NaN
# 1     50.0     7.778175    89.0    44.500000    89.0
# 2   2931.0  1666.530628  3020.0  1006.666667  2970.0
# 3   6520.0  3074.208950  9540.0  2385.000000  9451.0
# 4   6520.0  2859.647129  9591.0  1918.200000  6571.0

# %%
d2['ageee'].tail(3)
# Out:
# 2    2970.0
# 3    9451.0
# 4    6571.0
# Name: ageee, dtype: float64

# %%
d2.sort_values(['cummulative_age','agee'],ascending=False)
# Out:
#    FellowShipId FirstName  agee  cummulative_age     mean_age  min_age  \
# 4          1008  Barromir    51           9591.0  1918.200000     39.0
# 3          1007    Elrond  6520           9540.0  2385.000000     39.0
# 2          1006   Legolas  2931           3020.0  1006.666667     39.0
# 1          1002   Samwise    39             89.0    44.500000     39.0
# 0          1001     Frodo    50             50.0    50.000000     50.0
#
#    max_age      std_age   expec          exc   ageee
# 4   6520.0  2859.647129  9591.0  1918.200000  6571.0
# 3   6520.0  3074.208950  9540.0  2385.000000  9451.0
# 2   2931.0  1666.530628  3020.0  1006.666667  2970.0
# 1     50.0     7.778175    89.0    44.500000    89.0
# 0     50.0          NaN    50.0    50.000000     NaN

# %%
d2.sort_index(ascending=False)
# Out:
#    FellowShipId FirstName  agee  cummulative_age     mean_age  min_age  \
# 4          1008  Barromir    51           9591.0  1918.200000     39.0
# 3          1007    Elrond  6520           9540.0  2385.000000     39.0
# 2          1006   Legolas  2931           3020.0  1006.666667     39.0
# 1          1002   Samwise    39             89.0    44.500000     39.0
# 0          1001     Frodo    50             50.0    50.000000     50.0
#
#    max_age      std_age   expec          exc   ageee
# 4   6520.0  2859.647129  9591.0  1918.200000  6571.0
# 3   6520.0  3074.208950  9540.0  2385.000000  9451.0
# 2   2931.0  1666.530628  3020.0  1006.666667  2970.0
# 1     50.0     7.778175    89.0    44.500000    89.0
# 0     50.0          NaN    50.0    50.000000     NaN

# %%
data['Item_Outlet_Sales'].nlargest(5)
# Out:
# 4888    10256.6490
# 4289     9779.9362
# 6409     9069.5276
# 4991     8508.9240
# 5752     8479.6288
# Name: Item_Outlet_Sales, dtype: float64

# %%
d2
# Out:
#    FellowShipId FirstName  agee  cummulative_age     mean_age  min_age  \
# 0          1001     Frodo    50             50.0    50.000000     50.0
# 1          1002   Samwise    39             89.0    44.500000     39.0
# 2          1006   Legolas  2931           3020.0  1006.666667     39.0
# 3          1007    Elrond  6520           9540.0  2385.000000     39.0
# 4          1008  Barromir    51           9591.0  1918.200000     39.0
#
#    max_age      std_age   expec          exc   ageee
# 0     50.0          NaN    50.0    50.000000     NaN
# 1     50.0     7.778175    89.0    44.500000    89.0
# 2   2931.0  1666.530628  3020.0  1006.666667  2970.0
# 3   6520.0  3074.208950  9540.0  2385.000000  9451.0
# 4   6520.0  2859.647129  9591.0  1918.200000  6571.0

# %%
d2
# Out:
#    FellowShipId FirstName  agee  cummulative_age     mean_age  min_age  \
# 0          1001     Frodo    50             50.0    50.000000     50.0
# 1          1002   Samwise    39             89.0    44.500000     39.0
# 2          1006   Legolas  2931           3020.0  1006.666667     39.0
# 3          1007    Elrond  6520           9540.0  2385.000000     39.0
# 4          1008  Barromir    51           9591.0  1918.200000     39.0
#
#    max_age      std_age   expec          exc   ageee
# 0     50.0          NaN    50.0    50.000000     NaN
# 1     50.0     7.778175    89.0    44.500000    89.0
# 2   2931.0  1666.530628  3020.0  1006.666667  2970.0
# 3   6520.0  3074.208950  9540.0  2385.000000  9451.0
# 4   6520.0  2859.647129  9591.0  1918.200000  6571.0

# %%
def row_sum(row):
    return row.sum()

# %%
d2.apply(row_sum)
# Out:
# FellowShipId                                    5024
# FirstName          FrodoSamwiseLegolasElrondBarromir
# agee                                            9591
# cummulative_age                              22290.0
# mean_age                                 5404.366667
# min_age                                        206.0
# max_age                                      16071.0
# std_age                                  7608.164881
# expec                                        22290.0
# exc                                      5404.366667
# ageee                                        19081.0
# dtype: object

# %%
def column_sum(column):
    return column.sum()

# %%
d2.apply(column_sum)
# Out:
# FellowShipId                                    5024
# FirstName          FrodoSamwiseLegolasElrondBarromir
# agee                                            9591
# cummulative_age                              22290.0
# mean_age                                 5404.366667
# min_age                                        206.0
# max_age                                      16071.0
# std_age                                  7608.164881
# expec                                        22290.0
# exc                                      5404.366667
# ageee                                        19081.0
# dtype: object

# %%
def multiply_by_2(d2):
    return 2*d2

# %%
d2.pipe(multiply_by_2)
# Out:
#    FellowShipId         FirstName   agee  cummulative_age     mean_age  \
# 0          2002        FrodoFrodo    100            100.0   100.000000
# 1          2004    SamwiseSamwise     78            178.0    89.000000
# 2          2012    LegolasLegolas   5862           6040.0  2013.333333
# 3          2014      ElrondElrond  13040          19080.0  4770.000000
# 4          2016  BarromirBarromir    102          19182.0  3836.400000
#
#    min_age  max_age      std_age    expec          exc    ageee
# 0    100.0    100.0          NaN    100.0   100.000000      NaN
# 1     78.0    100.0    15.556349    178.0    89.000000    178.0
# 2     78.0   5862.0  3333.061256   6040.0  2013.333333   5940.0
# 3     78.0  13040.0  6148.417899  19080.0  4770.000000  18902.0
# 4     78.0  13040.0  5719.294257  19182.0  3836.400000  13142.0

# %%
d2.dtypes
# Out:
# FellowShipId         int64
# FirstName           object
# agee                 int64
# cummulative_age    float64
# mean_age           float64
# min_age            float64
# max_age            float64
# std_age            float64
# expec              float64
# exc                float64
# ageee              float64
# dtype: object

# %%
d2['agee'].astype(str,copy=True)
# Out:
# 0      50
# 1      39
# 2    2931
# 3    6520
# 4      51
# Name: agee, dtype: object

# %%
d2
# Out:
#    FellowShipId FirstName  agee  cummulative_age     mean_age  min_age  \
# 0          1001     Frodo    50             50.0    50.000000     50.0
# 1          1002   Samwise    39             89.0    44.500000     39.0
# 2          1006   Legolas  2931           3020.0  1006.666667     39.0
# 3          1007    Elrond  6520           9540.0  2385.000000     39.0
# 4          1008  Barromir    51           9591.0  1918.200000     39.0
#
#    max_age      std_age   expec          exc   ageee
# 0     50.0          NaN    50.0    50.000000     NaN
# 1     50.0     7.778175    89.0    44.500000    89.0
# 2   2931.0  1666.530628  3020.0  1006.666667  2970.0
# 3   6520.0  3074.208950  9540.0  2385.000000  9451.0
# 4   6520.0  2859.647129  9591.0  1918.200000  6571.0

# %%
d2.query('agee>50 and cummulative_age>50 and mean_age>50')
# Out:
#    FellowShipId FirstName  agee  cummulative_age     mean_age  min_age  \
# 2          1006   Legolas  2931           3020.0  1006.666667     39.0
# 3          1007    Elrond  6520           9540.0  2385.000000     39.0
# 4          1008  Barromir    51           9591.0  1918.200000     39.0
#
#    max_age      std_age   expec          exc   ageee
# 2   2931.0  1666.530628  3020.0  1006.666667  2970.0
# 3   6520.0  3074.208950  9540.0  2385.000000  9451.0
# 4   6520.0  2859.647129  9591.0  1918.200000  6571.0

# %%
d2
# Out:
#    FellowShipId FirstName  agee  cummulative_age     mean_age  min_age  \
# 0          1001     Frodo    50             50.0    50.000000     50.0
# 1          1002   Samwise    39             89.0    44.500000     39.0
# 2          1006   Legolas  2931           3020.0  1006.666667     39.0
# 3          1007    Elrond  6520           9540.0  2385.000000     39.0
# 4          1008  Barromir    51           9591.0  1918.200000     39.0
#
#    max_age      std_age   expec          exc   ageee
# 0     50.0          NaN    50.0    50.000000     NaN
# 1     50.0     7.778175    89.0    44.500000    89.0
# 2   2931.0  1666.530628  3020.0  1006.666667  2970.0
# 3   6520.0  3074.208950  9540.0  2385.000000  9451.0
# 4   6520.0  2859.647129  9591.0  1918.200000  6571.0

# %%
data
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 2          17.500          Low Fat         0.016760                   Meat
# 4           8.930          Low Fat         0.000000              Household
# 5          10.395          Regular         0.000000           Baking Goods
# 6          13.650          Regular         0.012741            Snack Foods
# 10         11.800          Low Fat         0.000000  Fruits and Vegetables
# ...           ...              ...              ...                    ...
# 8517       20.750              reg         0.083607           Frozen Foods
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
#       Item_MRP Outlet_Identifier  \
# ...

# %%
data.groupby('Outlet_Size').Item_Weight.mean()
# Out:
# Outlet_Size
# High      13.006148
# Medium    12.901115
# Small     12.848075
# Name: Item_Weight, dtype: float64

# %%
data.groupby('Item_Weight').Item_Outlet_Sales.sum()
# Out:
# Item_Weight
# 4.555      7046.8272
# 4.590      5093.3700
# 4.610      7500.9028
# 4.615      9787.2600
# 4.635      6296.4706
#              ...
# 21.000     5231.1906
# 21.100    27592.0836
# 21.200     7819.8210
# 21.250    33136.8660
# 21.350    23029.3562
# Name: Item_Outlet_Sales, Length: 409, dtype: float64
